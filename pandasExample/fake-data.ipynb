# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown as md

# %%
n = 100

# %%
df = pd.DataFrame({'Store': np.random.choice(['Store_1', 'Store_2'], n),
   'Product': np.random.choice(['Product_1',
   'Product_2'], n),
   'Revenue': (np.random.random(n) * 50 + 10).round(2),
   'Quantity': np.random.randint(1, 10, size=n)})

# %%
df.head(3)
# Out:
#      Store    Product  Revenue  Quantity
# 0  Store_1  Product_2    29.97         9
# 1  Store_2  Product_1    50.41         1
# 2  Store_1  Product_2    51.51         3

# %%
df.info
# Out:
# <bound method DataFrame.info of       Store    Product  Revenue  Quantity
# 0   Store_1  Product_2    29.97         9
# 1   Store_2  Product_1    50.41         1
# 2   Store_1  Product_2    51.51         3
# 3   Store_1  Product_1    13.44         3
# 4   Store_2  Product_2    31.72         6
# 5   Store_2  Product_2    30.68         7
# 6   Store_1  Product_1    57.91         3
# 7   Store_1  Product_2    56.34         4
# 8   Store_1  Product_1    40.66         8
# 9   Store_1  Product_1    22.52         6
# 10  Store_2  Product_2    17.47         6
# 11  Store_2  Product_2    51.35         5
# 12  Store_2  Product_2    22.92         5
# 13  Store_2  Product_2    46.37         1
# 14  Store_2  Product_2    42.24         7
# 15  Store_1  Product_1    50.76         7
# 16  Store_2  Product_1    18.45         7
# 17  Store_2  Product_2    54.04         8
# 18  Store_2  Product_2    14.40         9
# 19  Store_2  Product_2    36.62         2
# 20  Store_2  Product_1    14.80         2
# ...

# %%
df1 = df.groupby(['Store', 'Product']).pipe(lambda grp: grp.Revenue.sum())

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
df1.index
# Out:
# MultiIndex(levels=[['Store_1', 'Store_2'], ['Product_1', 'Product_2']],
#            codes=[[0, 0, 1, 1], [0, 1, 0, 1]],
#            names=['Store', 'Product'])

# %%
df1
# Out:
# Store    Product
# Store_1  Product_1     905.46
#          Product_2     752.02
# Store_2  Product_1     645.97
#          Product_2    1090.10
# Name: Revenue, dtype: float64

# %%
df2 = df1.reset_index()

# %%
df3 = df1.unstack()

# %%
df2
# Out:
#      Store    Product  Revenue
# 0  Store_1  Product_1   905.46
# 1  Store_1  Product_2   752.02
# 2  Store_2  Product_1   645.97
# 3  Store_2  Product_2  1090.10

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3
# Out:
# Product  Product_1  Product_2
# Store
# Store_1     905.46     752.02
# Store_2     645.97    1090.10

# %%
df3.columns
# Out:
# Index(['Product_1', 'Product_2'], dtype='object', name='Product')

# %%
df3.index
# Out:
# Index(['Store_1', 'Store_2'], dtype='object', name='Store')

# %%
df4 = df3.iloc[0]

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df4.index
# Out:
# Index(['Product_1', 'Product_2'], dtype='object', name='Product')

# %%
df4
# Out:
# Product
# Product_1    905.46
# Product_2    752.02
# Name: Store_1, dtype: float64

# %%
df3.iloc[1]
# Out:
# Product
# Product_1     645.97
# Product_2    1090.10
# Name: Store_2, dtype: float64

# %%
for name, group in df1:
    print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-b03eec754ac3> in <module>
# ----> 1 for name, group in df1:
#       2     print(name)
#
# TypeError: cannot unpack non-iterable float object

# %%
(df.groupby(['Store', 'Product'])
   .pipe(lambda grp: grp.Revenue.sum() / grp.Quantity.sum())
   .unstack().round(2))
# Out:
# Product  Product_1  Product_2
# Store
# Store_1       7.27       5.81
# Store_2       5.59       7.73

# %% [markdown]
# ### Get the data set from https://www.kaggle.com/currie32/crimes-in-chicago

# %%
data = pd.read_csv("chicago_crime_data.csv")

# %%
data.shape
# Out:
# (265382, 22)

# %%
md("### The data frame has %i Records and %i Columns"%(data.shape[0], data.shape[1]))
# Out:
# ### The data frame has 265382 Records and 22 Columns

# %%
data.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
data.head(3)
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0     24392    JB323792  06/26/2018 05:16:00 PM       077XX S COLES AVE  0110
# 1  11582357    JC136122  12/26/2018 08:00:00 AM  008XX N CHRISTIANA AVE  1153
# 2  11582352    JC136052  12/01/2018 12:00:00 AM      030XX S KARLOV AVE  5000
#
#          Primary Type                          Description  \
# 0            HOMICIDE                  FIRST DEGREE MURDER
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 2       OTHER OFFENSE           OTHER CRIME AGAINST PERSON
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0                 YARD   False     False  ...   7.0            43.0       01A
# 1                OTHER   False     False  ...  27.0            23.0        11
# 2            APARTMENT   False     False  ...  22.0            30.0        26
#
#    X Coordinate Y Coordinate  Year              Updated On  Latitude  \
# ...

# %%
data.tail(3)
# Out:
#               ID Case Number                    Date                 Block  \
# 265379     23758    JB100522  01/01/2018 11:33:00 AM    026XX N HAMPDEN CT
# 265380     23757    JB100159  01/01/2018 02:46:00 AM  039XX W CORNELIA AVE
# 265381  11193631    JB102174  01/02/2018 12:30:00 PM   0000X N LA SALLE ST
#
#         IUCR Primary Type          Description Location Description  Arrest  \
# 265379  0110     HOMICIDE  FIRST DEGREE MURDER            APARTMENT   False
# 265380  0110     HOMICIDE  FIRST DEGREE MURDER                 AUTO   False
# 265381  0870        THEFT       POCKET-PICKING           RESTAURANT   False
#
#         Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 265379     False  ...  43.0             7.0       01A     1172664.0
# 265380     False  ...  30.0            21.0       01A     1149289.0
# 265381     False  ...  42.0            32.0        06           NaN
#
#        Y Coordinate  Year              Updated On   Latitude  Longitude  \
# ...

# %%
data.info() #Summary of the Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265382 entries, 0 to 265381
# Data columns (total 22 columns):
# ID                      265382 non-null int64
# Case Number             265382 non-null object
# Date                    265382 non-null object
# Block                   265382 non-null object
# IUCR                    265382 non-null object
# Primary Type            265382 non-null object
# Description             265382 non-null object
# Location Description    264637 non-null object
# Arrest                  265382 non-null bool
# Domestic                265382 non-null bool
# Beat                    265382 non-null int64
# District                265382 non-null int64
# Ward                    265379 non-null float64
# Community Area          265380 non-null float64
# FBI Code                265382 non-null object
# X Coordinate            263653 non-null float64
# Y Coordinate            263653 non-null float64
# Year                    265382 non-null int64
# ...

# %%
data["FBI Code"].unique()
# Out:
# array(['01A', '11', '26', '06', '10', '05', '03', '14', '02', '17', '20',
#        '08B', '04B', '07', '04A', '08A', '24', '15', '16', '18', '09',
#        '01B', '12', '22', '13', '19'], dtype=object)

# %%
md("### The data frame has in total %i FBI Codes "%(len(data["FBI Code"].unique())))
# Out:
# ### The data frame has in total 26 FBI Codes

# %%
data['Date'] = pd.to_datetime(data['Date'] )

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265382 entries, 0 to 265381
# Data columns (total 22 columns):
# ID                      265382 non-null int64
# Case Number             265382 non-null object
# Date                    265382 non-null datetime64[ns]
# Block                   265382 non-null object
# IUCR                    265382 non-null object
# Primary Type            265382 non-null object
# Description             265382 non-null object
# Location Description    264637 non-null object
# Arrest                  265382 non-null bool
# Domestic                265382 non-null bool
# Beat                    265382 non-null int64
# District                265382 non-null int64
# Ward                    265379 non-null float64
# Community Area          265380 non-null float64
# FBI Code                265382 non-null object
# X Coordinate            263653 non-null float64
# Y Coordinate            263653 non-null float64
# ...

# %% [markdown]
# ### min(), max(), sum(), mean(), median(), mode(), can be applied for column values

# %%
data['Latitude'].min()
# Out:
# 41.644589713

# %%
data['Latitude'].max()
# Out:
# 42.022671246

# %%
data.isna().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description     745
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       3
# Community Area             2
# FBI Code                   0
# X Coordinate            1729
# Y Coordinate            1729
# Year                       0
# Updated On                 0
# Latitude                1729
# Longitude               1729
# Location                1729
# dtype: int64

# %%
type(data.isna().sum())
# Out:
# pandas.core.series.Series

# %%
data.isna().sum().axes
# Out:
# [Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#         'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#         'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#         'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#         'Location'],
#        dtype='object')]

# %% [markdown]
# ### Fill null values for Ward with the current average

# %%
ward_mean = data['Ward'].mean()

# %%
ward_mean
# Out:
# 23.439450747798432

# %%
data['Ward'] = data['Ward'].fillna(value = ward_mean)

# %%
data.isna().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description     745
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       0
# Community Area             2
# FBI Code                   0
# X Coordinate            1729
# Y Coordinate            1729
# Year                       0
# Updated On                 0
# Latitude                1729
# Longitude               1729
# Location                1729
# dtype: int64

# %% [markdown]
# ### Delete the rows with na values

# %%
data.dropna(axis=0, inplace=True)

# %%
data.isna().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %%
data.head(3)
# Out:
#          ID Case Number                Date                 Block  IUCR  \
# 6  11492177    JB496165 2018-10-29 21:45:00   073XX S CHAPPEL AVE  0820
# 7  11492004    JB495913 2018-10-29 13:00:00   065XX S KIMBARK AVE  0820
# 8  11488952    JB491843 2018-10-27 02:00:00  070XX S JEFFERY BLVD  0820
#
#   Primary Type     Description Location Description  Arrest  Domestic  ...  \
# 6        THEFT  $500 AND UNDER               STREET   False     False  ...
# 7        THEFT  $500 AND UNDER               STREET   False     False  ...
# 8        THEFT  $500 AND UNDER               STREET   False     False  ...
#
#    Ward  Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 6   7.0            43.0        06     1191153.0    1856737.0  2018
# 7  20.0            42.0        06     1185761.0    1861970.0  2018
# 8   5.0            43.0        06     1190765.0    1858575.0  2018
#
#                Updated On   Latitude  Longitude                       Location
# ...

# %%
### Delete in the rows do not reset the index

# %%
data.reset_index(inplace = True, drop=True)

# %%
data.head(3)
# Out:
#          ID Case Number                Date                 Block  IUCR  \
# 0  11492177    JB496165 2018-10-29 21:45:00   073XX S CHAPPEL AVE  0820
# 1  11492004    JB495913 2018-10-29 13:00:00   065XX S KIMBARK AVE  0820
# 2  11488952    JB491843 2018-10-27 02:00:00  070XX S JEFFERY BLVD  0820
#
#   Primary Type     Description Location Description  Arrest  Domestic  ...  \
# 0        THEFT  $500 AND UNDER               STREET   False     False  ...
# 1        THEFT  $500 AND UNDER               STREET   False     False  ...
# 2        THEFT  $500 AND UNDER               STREET   False     False  ...
#
#    Ward  Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0   7.0            43.0        06     1191153.0    1856737.0  2018
# 1  20.0            42.0        06     1185761.0    1861970.0  2018
# 2   5.0            43.0        06     1190765.0    1858575.0  2018
#
#                Updated On   Latitude  Longitude                       Location
# ...

# %%
data.iloc[[0]]
# Out:
#          ID Case Number                Date                Block  IUCR  \
# 0  11492177    JB496165 2018-10-29 21:45:00  073XX S CHAPPEL AVE  0820
#
#   Primary Type     Description Location Description  Arrest  Domestic  ...  \
# 0        THEFT  $500 AND UNDER               STREET   False     False  ...
#
#    Ward  Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0   7.0            43.0        06     1191153.0    1856737.0  2018
#
#                Updated On   Latitude Longitude                       Location
# 0  01/30/2019 04:08:28 PM  41.761894 -87.57496  (41.761893792, -87.574959656)
#
# [1 rows x 22 columns]

# %%
data.iloc[3:6]
# Out:
#          ID Case Number                Date                   Block  IUCR  \
# 3  11488097    JB490633 2018-10-24 06:00:00  063XX S DORCHESTER AVE  0820
# 4  11481439    JB482043 2018-10-18 16:00:00     069XX S CRANDON AVE  0820
# 5  11480921    JB481242 2018-10-18 20:30:00     065XX S KIMBARK AVE  0820
#
#   Primary Type     Description            Location Description  Arrest  \
# 3        THEFT  $500 AND UNDER  PARKING LOT/GARAGE(NON.RESID.)   False
# 4        THEFT  $500 AND UNDER                       RESIDENCE   False
# 5        THEFT  $500 AND UNDER                          STREET   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# 3     False  ...  20.0            42.0        06     1186589.0    1863270.0
# 4     False  ...   5.0            43.0        06     1192521.0    1859491.0
# 5     False  ...  20.0            42.0        06     1185761.0    1861970.0
#
#    Year              Updated On   Latitude  Longitude  \
# ...

# %%
data[['Date', 'Block']].iloc[[5]]
# Out:
#                  Date                Block
# 5 2018-10-18 20:30:00  065XX S KIMBARK AVE

# %%
data[['Date', 'Block']][5:6]
# Out:
#                  Date                Block
# 5 2018-10-18 20:30:00  065XX S KIMBARK AVE

# %%
data.iloc[4:8,2:4]
# Out:
#                  Date                 Block
# 4 2018-10-18 16:00:00   069XX S CRANDON AVE
# 5 2018-10-18 20:30:00   065XX S KIMBARK AVE
# 6 2018-10-16 21:30:00  061XX S WOODLAWN AVE
# 7 2018-10-14 05:00:00  071XX S JEFFERY BLVD

# %%
data.iloc[4:8,-1]
# Out:
# 4    (41.769417774, -87.569856281)
# 5    (41.776382364, -87.594556922)
# 6    (41.783709683, -87.596276769)
# 7     (41.76587359, -87.576294705)
# Name: Location, dtype: object

# %%
a = (data.Ward < 30)

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13        False
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21        False
# 22        False
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29        False
#           ...
# 262982     True
# 262983     True
# 262984    False
# 262985     True
# 262986     True
# 262987     True
# 262988    False
# 262989     True
# 262990     True
# 262991    False
# 262992     True
# 262993    False
# 262994     True
# 262995     True
# 262996    False
# 262997     True
# 262998    False
# 262999    False
# 263000     True
# 263001    False
# 263002    False
# 263003     True
# 263004     True
# 263005     True
# ...

# %%
s1 = pd.Series([False] * 263012, index=range(0, 263012))

# %%
s1.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
data.loc[a]
# Out:
#               ID Case Number                Date                      Block  \
# 0       11492177    JB496165 2018-10-29 21:45:00        073XX S CHAPPEL AVE
# 1       11492004    JB495913 2018-10-29 13:00:00        065XX S KIMBARK AVE
# 2       11488952    JB491843 2018-10-27 02:00:00       070XX S JEFFERY BLVD
# 3       11488097    JB490633 2018-10-24 06:00:00     063XX S DORCHESTER AVE
# 4       11481439    JB482043 2018-10-18 16:00:00        069XX S CRANDON AVE
# 5       11480921    JB481242 2018-10-18 20:30:00        065XX S KIMBARK AVE
# 6       11478932    JB478700 2018-10-16 21:30:00       061XX S WOODLAWN AVE
# 7       11476211    JB475196 2018-10-14 05:00:00       071XX S JEFFERY BLVD
# 8       11473764    JB471936 2018-10-06 01:00:00     072XX S SOUTH SHORE DR
# 9       11469473    JB466082 2018-10-02 22:00:00       073XX S PHILLIPS AVE
# 10      11465469    JB460756 2018-10-03 01:00:00        063XX S MINERVA AVE
# ...

# %%
data_arrest = (data.loc[(data['Arrest'] == True)])

# %%
data_arrest.reset_index(drop=True, inplace=True)

# %%
data_arrest
# Out:
#              ID Case Number                Date  \
# 0      11346714    JB305536 2018-06-11 12:30:00
# 1      11560167    JC103552 2018-12-29 19:00:00
# 2      11546276    JB566896 2018-12-25 11:30:00
# 3      11542091    JB561201 2018-12-12 20:42:00
# 4      11541363    JB560864 2018-12-20 10:37:00
# 5      11536723    JB555098 2018-12-15 21:15:00
# 6      11534484    JB552117 2018-12-13 08:00:00
# 7      11532394    JB549386 2018-12-11 12:30:00
# 8      11530142    JB546327 2018-10-18 11:00:00
# 9      11525869    JB540499 2018-12-04 20:54:00
# 10     11497756    JB503467 2018-11-04 17:45:00
# 11     11493960    JB498187 2018-10-31 19:11:00
# 12     11480451    JB480643 2018-10-03 15:10:00
# 13     11471939    JB469337 2018-10-09 21:08:00
# 14     11470046    JB466774 2018-10-08 05:40:00
# 15     11386131    JB357097 2018-07-19 17:00:00
# 16     11376786    JB345306 2018-06-20 19:25:00
# 17     11540979    JB560418 2018-12-19 21:23:00
# ...

# %%
data['lat'], data['long'] = data['Location'].str.split(',', 1).str

# %%
data.head(3)
# Out:
#          ID Case Number                Date                 Block  IUCR  \
# 0  11492177    JB496165 2018-10-29 21:45:00   073XX S CHAPPEL AVE  0820
# 1  11492004    JB495913 2018-10-29 13:00:00   065XX S KIMBARK AVE  0820
# 2  11488952    JB491843 2018-10-27 02:00:00  070XX S JEFFERY BLVD  0820
#
#   Primary Type     Description Location Description  Arrest  Domestic  ...  \
# 0        THEFT  $500 AND UNDER               STREET   False     False  ...
# 1        THEFT  $500 AND UNDER               STREET   False     False  ...
# 2        THEFT  $500 AND UNDER               STREET   False     False  ...
#
#    FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 0        06     1191153.0     1856737.0  2018  01/30/2019 04:08:28 PM
# 1        06     1185761.0     1861970.0  2018  01/30/2019 04:08:28 PM
# 2        06     1190765.0     1858575.0  2018  01/30/2019 04:08:28 PM
#
#     Latitude  Longitude                       Location            lat  \
# ...

# %%
data['lat'] = data['lat'].str.replace('(', '')

# %%
data['long'] = data['long'].str.replace(')', '')

# %%
data.head(3)
# Out:
#          ID Case Number                Date                 Block  IUCR  \
# 0  11492177    JB496165 2018-10-29 21:45:00   073XX S CHAPPEL AVE  0820
# 1  11492004    JB495913 2018-10-29 13:00:00   065XX S KIMBARK AVE  0820
# 2  11488952    JB491843 2018-10-27 02:00:00  070XX S JEFFERY BLVD  0820
#
#   Primary Type     Description Location Description  Arrest  Domestic  ...  \
# 0        THEFT  $500 AND UNDER               STREET   False     False  ...
# 1        THEFT  $500 AND UNDER               STREET   False     False  ...
# 2        THEFT  $500 AND UNDER               STREET   False     False  ...
#
#    FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 0        06     1191153.0     1856737.0  2018  01/30/2019 04:08:28 PM
# 1        06     1185761.0     1861970.0  2018  01/30/2019 04:08:28 PM
# 2        06     1190765.0     1858575.0  2018  01/30/2019 04:08:28 PM
#
#     Latitude  Longitude                       Location           lat  \
# ...

# %%
data.drop(['lat' , 'long'], inplace=True, axis=1)

# %% [markdown]
# ### Grouping the data frame based on Primary Type

# %%
group_by = data.groupby(['Primary Type']).count()
# Out:
#                                       ID  Case Number   Date  Block   IUCR  \
# Primary Type
# ARSON                                372          372    372    372    372
# ASSAULT                            20344        20344  20344  20344  20344
# BATTERY                            49733        49733  49733  49733  49733
# BURGLARY                           11687        11687  11687  11687  11687
# CONCEALED CARRY LICENSE VIOLATION    148          148    148    148    148
# CRIM SEXUAL ASSAULT                 1583         1583   1583   1583   1583
# CRIMINAL DAMAGE                    27705        27705  27705  27705  27705
# CRIMINAL TRESPASS                   6880         6880   6880   6880   6880
# DECEPTIVE PRACTICE                 17247        17247  17247  17247  17247
# GAMBLING                             201          201    201    201    201
# HOMICIDE                             584          584    584    584    584
# ...

# %%
sorted = data.sort_values(by=['Date'], ascending=True).reset_index()

# %%
sorted.head(4)
# Out:
#     index        ID Case Number       Date                 Block  IUCR  \
# 0  250284  11212228    JB127156 2018-01-01    109XX S HALSTED ST  0810
# 1  192302  11294302    JB235992 2018-01-01    003XX N KEDZIE AVE  0810
# 2  137254  11372246    JB339225 2018-01-01  004XX N RIDGEWAY AVE  1153
# 3  218548  11257074    JB184108 2018-01-01  051XX W SCHUBERT AVE  0266
#
#           Primary Type                          Description  \
# 0                THEFT                            OVER $500
# 1                THEFT                            OVER $500
# 2   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 3  CRIM SEXUAL ASSAULT                            PREDATORY
#
#            Location Description  Arrest  ...  Ward  Community Area  FBI Code  \
# 0  NURSING HOME/RETIREMENT HOME   False  ...  34.0            49.0        06
# 1                        STREET   False  ...  28.0            27.0        06
# ...
